# %%
import pandas as pd

summary_path = "/home/tunguyen/energyfl/outputcifar10/10clients/fedadagrad/labelskew/experiment_summary.csv"
summary = pd.read_csv(summary_path)
summary.T
# Out:
#                                                                                          0   \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-10.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-03-30_16-21-25_008883
# timestamps.start_experiment                                      2024-03-30_16-21-55_039318
# timestamps.end_experiment                                        2024-03-30_21-49-14_951786
# timestamps.end_experiment_after_sleep                            2024-03-30_21-49-44_977251
# params.num_rounds                                                                      1000
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     0.3
# params.fraction_evaluate                                                                0.5
# params.wait_round                                                                      1000
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       1
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.10
# comm.port                                                                              8080
#
#                                                                                          1   \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-10.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-03-30_23-25-52_120457
# timestamps.start_experiment                                      2024-03-30_23-26-22_149414
# timestamps.end_experiment                                        2024-03-31_07-28-47_896001
# timestamps.end_experiment_after_sleep                            2024-03-31_07-29-17_925220
# params.num_rounds                                                                      1000
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                      1000
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       1
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.10
# comm.port                                                                              8080
#
#                                                                                          2   \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-10.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-03-31_07-29-25_643280
# timestamps.start_experiment                                      2024-03-31_07-29-55_673615
# timestamps.end_experiment                                        2024-04-01_08-45-17_328111
# timestamps.end_experiment_after_sleep                            2024-04-01_08-45-47_359386
# params.num_rounds                                                                      1000
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                      1000
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                      10
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.10
# comm.port                                                                              8080
#
#                                                                                          3   \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-10.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-01_08-47-06_411240
# timestamps.start_experiment                                      2024-04-01_08-47-36_421452
# timestamps.end_experiment                                        2024-04-01_08-47-41_427135
# timestamps.end_experiment_after_sleep                            2024-04-01_08-48-11_429321
# params.num_rounds                                                                      1000
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                      1000
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       5
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                            Failed
# comm.port                                                                              8080
#
#                                                                                          4   \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-10.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-01_08-49-30_524562
# timestamps.start_experiment                                      2024-04-01_08-50-00_542407
# timestamps.end_experiment                                        2024-04-01_08-50-05_549789
# timestamps.end_experiment_after_sleep                            2024-04-01_08-50-35_580165
# params.num_rounds                                                                      1000
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                      1000
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       3
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                            Failed
# comm.port                                                                              8080
#
#                                                                                          5   \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-10.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-02_13-53-46_488943
# timestamps.start_experiment                                      2024-04-02_13-54-16_519288
# timestamps.end_experiment                                        2024-04-02_16-02-30_610813
# timestamps.end_experiment_after_sleep                            2024-04-02_16-03-00_641316
# params.num_rounds                                                                       300
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       300
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       1
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.10
# comm.port                                                                              8080
#
#                                                                                          6   \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-10.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-02_16-13-35_498323
# timestamps.start_experiment                                      2024-04-02_16-14-05_528732
# timestamps.end_experiment                                        2024-04-02_18-21-12_577271
# timestamps.end_experiment_after_sleep                            2024-04-02_18-21-42_607738
# params.num_rounds                                                                       300
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       300
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       1
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.10
# comm.port                                                                              8080
#
#                                                                                          7   \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-10.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-03_10-49-24_284825
# timestamps.start_experiment                                      2024-04-03_10-49-54_316251
# timestamps.end_experiment                                        2024-04-03_14-11-41_740264
# timestamps.end_experiment_after_sleep                            2024-04-03_14-12-11_754280
# params.num_rounds                                                                       300
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       300
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       3
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.10
# comm.port                                                                              8080
#
#                                                                                          8   \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-10.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-03_14-12-18_784195
# timestamps.start_experiment                                      2024-04-03_14-12-48_797485
# timestamps.end_experiment                                        2024-04-03_16-18-30_174971
# timestamps.end_experiment_after_sleep                            2024-04-03_16-19-00_205385
# params.num_rounds                                                                       300
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       300
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       1
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.10
# comm.port                                                                              8080
#
#                                                                                          9   \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-10.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-03_16-44-10_911916
# timestamps.start_experiment                                      2024-04-03_16-44-40_937495
# timestamps.end_experiment                                        2024-04-03_18-51-13_506232
# timestamps.end_experiment_after_sleep                            2024-04-03_18-51-43_517149
# params.num_rounds                                                                       300
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       300
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       1
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.10
# comm.port                                                                              8080
#
#                                           ...  \
# result_folder                             ...
# energy_file                               ...
# server                                    ...
# sleep_duration                            ...
# neuralnet                                 ...
# strategy                                  ...
# optimizer                                 ...
# timestamps.start_experiment_before_sleep  ...
# timestamps.start_experiment               ...
# timestamps.end_experiment                 ...
# timestamps.end_experiment_after_sleep     ...
# params.num_rounds                         ...
# params.num_clients_per_round_fit          ...
# params.num_clients_per_round_eval         ...
# params.min_available_clients              ...
# params.fraction_fit                       ...
# params.fraction_evaluate                  ...
# params.wait_round                         ...
# params.lr                                 ...
# params.num_groups                         ...
# data.data_name                            ...
# data.batch_size                           ...
# data.validation_split                     ...
# data.num_clients                          ...
# data.alpha                                ...
# data.partition                            ...
# client.lr                                 ...
# client.local_epochs                       ...
# client.decay_rate                         ...
# client.decay_steps                        ...
# comm.host                                 ...
# comm.port                                 ...
#
#                                                                                          13  \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-10.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-08_13-31-43_809251
# timestamps.start_experiment                                      2024-04-08_13-32-13_839468
# timestamps.end_experiment                                        2024-04-08_15-05-37_523973
# timestamps.end_experiment_after_sleep                            2024-04-08_15-06-07_554444
# params.num_rounds                                                                       100
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       100
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       5
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.10
# comm.port                                                                              8080
#
#                                                                                          14  \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-10.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-08_15-06-14_212404
# timestamps.start_experiment                                      2024-04-08_15-06-44_242667
# timestamps.end_experiment                                        2024-04-08_15-51-45_041893
# timestamps.end_experiment_after_sleep                            2024-04-08_15-52-15_071377
# params.num_rounds                                                                       100
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       100
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       3
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.10
# comm.port                                                                              8080
#
#                                                                                          15  \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-11.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-08_20-32-05_750941
# timestamps.start_experiment                                      2024-04-08_20-32-35_773302
# timestamps.end_experiment                                        2024-04-08_21-41-06_158595
# timestamps.end_experiment_after_sleep                            2024-04-08_21-41-36_189075
# params.num_rounds                                                                       100
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       100
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       3
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.11
# comm.port                                                                              8080
#
#                                                                                          16  \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-11.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-08_21-41-44_582714
# timestamps.start_experiment                                      2024-04-08_21-42-14_597244
# timestamps.end_experiment                                        2024-04-08_22-49-26_129424
# timestamps.end_experiment_after_sleep                            2024-04-08_22-49-56_159924
# params.num_rounds                                                                       100
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       100
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       3
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.11
# comm.port                                                                              8080
#
#                                                                                          17  \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-11.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-08_22-50-02_667878
# timestamps.start_experiment                                      2024-04-08_22-50-32_698213
# timestamps.end_experiment                                        2024-04-09_00-23-14_801209
# timestamps.end_experiment_after_sleep                            2024-04-09_00-23-44_831609
# params.num_rounds                                                                       100
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       100
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# ...
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.11
# comm.port                                                                              8080
#
#                                                                                          18  \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-11.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-09_00-23-53_361106
# timestamps.start_experiment                                      2024-04-09_00-24-23_391433
# timestamps.end_experiment                                        2024-04-09_01-32-06_500668
# timestamps.end_experiment_after_sleep                            2024-04-09_01-32-36_509605
# params.num_rounds                                                                       100
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       100
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       3
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.11
# comm.port                                                                              8080
#
#                                                                                          19  \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-11.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-09_01-32-43_135591
# timestamps.start_experiment                                      2024-04-09_01-33-13_153714
# timestamps.end_experiment                                        2024-04-09_03-06-04_990417
# timestamps.end_experiment_after_sleep                            2024-04-09_03-06-35_013400
# params.num_rounds                                                                       100
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       100
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       5
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.11
# comm.port                                                                              8080
#
#                                                                                          20  \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-11.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-09_03-06-43_735395
# timestamps.start_experiment                                      2024-04-09_03-07-13_765704
# timestamps.end_experiment                                        2024-04-09_04-40-37_490007
# timestamps.end_experiment_after_sleep                            2024-04-09_04-41-07_520561
# params.num_rounds                                                                       100
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       100
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       5
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.11
# comm.port                                                                              8080
#
#                                                                                          21  \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-11.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-09_04-41-14_196426
# timestamps.start_experiment                                      2024-04-09_04-41-44_226768
# timestamps.end_experiment                                        2024-04-09_05-48-56_541440
# timestamps.end_experiment_after_sleep                            2024-04-09_05-49-26_571888
# params.num_rounds                                                                       100
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       100
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       3
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.11
# comm.port                                                                              8080
#
#                                                                                          22
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-10.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-09_19-19-23_831392
# timestamps.start_experiment                                      2024-04-09_19-19-53_853575
# timestamps.end_experiment                                        2024-04-09_20-54-11_442356
# timestamps.end_experiment_after_sleep                            2024-04-09_20-54-41_465468
# params.num_rounds                                                                       100
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       100
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       5
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.10
# comm.port                                                                              8080
#
# [32 rows x 23 columns]

# %%
summary[summary["client.local_epochs"]==3].T
# Out:
#                                                                                          4   \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-10.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-01_08-49-30_524562
# timestamps.start_experiment                                      2024-04-01_08-50-00_542407
# timestamps.end_experiment                                        2024-04-01_08-50-05_549789
# timestamps.end_experiment_after_sleep                            2024-04-01_08-50-35_580165
# params.num_rounds                                                                      1000
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                      1000
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       3
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                            Failed
# comm.port                                                                              8080
#
#                                                                                          7   \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-10.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-03_10-49-24_284825
# timestamps.start_experiment                                      2024-04-03_10-49-54_316251
# timestamps.end_experiment                                        2024-04-03_14-11-41_740264
# timestamps.end_experiment_after_sleep                            2024-04-03_14-12-11_754280
# params.num_rounds                                                                       300
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       300
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       3
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.10
# comm.port                                                                              8080
#
#                                                                                          12  \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-10.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-08_12-18-39_223404
# timestamps.start_experiment                                      2024-04-08_12-19-09_234962
# timestamps.end_experiment                                        2024-04-08_13-26-33_733581
# timestamps.end_experiment_after_sleep                            2024-04-08_13-27-03_747553
# params.num_rounds                                                                       100
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       100
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       3
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.10
# comm.port                                                                              8080
#
#                                                                                          14  \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-10.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-08_15-06-14_212404
# timestamps.start_experiment                                      2024-04-08_15-06-44_242667
# timestamps.end_experiment                                        2024-04-08_15-51-45_041893
# timestamps.end_experiment_after_sleep                            2024-04-08_15-52-15_071377
# params.num_rounds                                                                       100
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       100
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       3
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.10
# comm.port                                                                              8080
#
#                                                                                          15  \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-11.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-08_20-32-05_750941
# timestamps.start_experiment                                      2024-04-08_20-32-35_773302
# timestamps.end_experiment                                        2024-04-08_21-41-06_158595
# timestamps.end_experiment_after_sleep                            2024-04-08_21-41-36_189075
# params.num_rounds                                                                       100
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       100
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       3
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.11
# comm.port                                                                              8080
#
#                                                                                          16  \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-11.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-08_21-41-44_582714
# timestamps.start_experiment                                      2024-04-08_21-42-14_597244
# timestamps.end_experiment                                        2024-04-08_22-49-26_129424
# timestamps.end_experiment_after_sleep                            2024-04-08_22-49-56_159924
# params.num_rounds                                                                       100
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       100
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       3
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.11
# comm.port                                                                              8080
#
#                                                                                          18  \
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-11.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-09_00-23-53_361106
# timestamps.start_experiment                                      2024-04-09_00-24-23_391433
# timestamps.end_experiment                                        2024-04-09_01-32-06_500668
# timestamps.end_experiment_after_sleep                            2024-04-09_01-32-36_509605
# params.num_rounds                                                                       100
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       100
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       3
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.11
# comm.port                                                                              8080
#
#                                                                                          21
# result_folder                             /root/energyfl/outputcifar10/10clients/fedadag...
# energy_file                                                                      energy.csv
# server                                                       estats-11.toulouse.grid5000.fr
# sleep_duration                                                                           30
# neuralnet                                                                          ResNet18
# strategy                                                                         fedadagrad
# optimizer                                                                               SGD
# timestamps.start_experiment_before_sleep                         2024-04-09_04-41-14_196426
# timestamps.start_experiment                                      2024-04-09_04-41-44_226768
# timestamps.end_experiment                                        2024-04-09_05-48-56_541440
# timestamps.end_experiment_after_sleep                            2024-04-09_05-49-26_571888
# params.num_rounds                                                                       100
# params.num_clients_per_round_fit                                                          2
# params.num_clients_per_round_eval                                                         2
# params.min_available_clients                                                              2
# params.fraction_fit                                                                     1.0
# params.fraction_evaluate                                                                1.0
# params.wait_round                                                                       100
# params.lr                                                                              0.01
# params.num_groups                                                                        32
# data.data_name                                                                      CIFAR10
# data.batch_size                                                                          64
# data.validation_split                                                                    20
# data.num_clients                                                                         10
# data.alpha                                                                              0.5
# data.partition                                                                   label_skew
# client.lr                                                                            0.0316
# client.local_epochs                                                                       3
# client.decay_rate                                                                         1
# client.decay_steps                                                                        1
# comm.host                                                                     172.16.121.11
# comm.port                                                                              8080

# %%
network = pd.read_csv("./utils/network.csv")

# %%
network.dtypes
# Out:
# Process     object
# Value1     float64
# Value2     float64
# dtype: object

# %%
import torchvision
#from torchsummary import summary
from utils.models import convert_bn_to_gn
model = torchvision.models.resnet18(pretrained=False,num_classes=10)
model = convert_bn_to_gn(model, num_groups=32)
# Out:
# /home/tunguyen/venv-fl/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/tunguyen/venv-fl/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
ok = [p.numel() for p in model.parameters()]

# %%
def cal_size(num_params,dtype):
    if dtype == "float32":
        size = (num_params/1024**2) * 4    
    elif dtype == "float16":
        size = (num_params/1024**2) * 2
    elif dtype == "int8":
        size = (num_params/1024**2) * 1
    else:
        size = -1
    print("Size of model is : {:.2f} MB".format(size))
    return size

# %%
cal_size(sum(ok), 'float32')
# Out:
# Size of model is :42.65 MB
# 42.654579162597656
